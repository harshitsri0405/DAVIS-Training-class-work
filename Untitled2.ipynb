# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitsri0405/DAVIS-Training-class-work/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_si(principal, rate, time):
    return (principal * rate * time) / 100

print("Simple Interest =", calculate_si(1000, 5, 2))
